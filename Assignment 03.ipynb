# %% [markdown]
# # Assingment 03
#
# # 2020136102 이승현

# %% [markdown]
# ### Q1. L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.
#
#
# 1)
# L[1:3] = [100]
# print(L)
# 2)
# L[1:3] = [(100)]
# print(L)
# 3)
# L[1:3] = 100
# print(L)
# 4)
# L[1:3] = (100)
# print(L)
# 5)
# L[1:3] = (100, 101, 102)
# print(L)
# 6)
# L[1:3] = [100, 101, 102]
# print(L)
# 7)
# L[1:3] = [(100, 101, 102)]
# print(L)
# 8)
# L[1:3] = [[100, 101, 102]]
# print(L)

# %%
#1
L=[1, 2, 3, 4, 5]
L[1:3] = [100]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# - 슬라이싱을 사용하여 인덱스의 범위가 1~2인 값을 삭제하고 해당 위치에 [100] 리스트를 넣는 것이기 때문에 [1,100,4,5]가 출력된다.

# %%
#2
L=[1, 2, 3, 4, 5]
L[1:3] = [(100)]
print(L)
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# - 슬라이싱을 사용하여 인덱스의 범위가 1~2인 값을 삭제하고 해당 위치에 [(100)] 즉, [100] 리스트를 넣는 것이기 때문에 [1,100,4,5]가 출력된다.

# %%
#3
L=[1, 2, 3, 4, 5]
L[1:3] = 100 
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-cb77d50e26ee> in <module>
#       1 #3
#       2 L=[1, 2, 3, 4, 5]
# ----> 3 L[1:3] = 100
#       4 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# - 조각 안에 리스트를 대입할 때, 대입하려고 하는 대상이 다른 리스트여야 한다. 위 코드에서는 정수 100이기 때문에 에러가 뜬다.

# %%
#4
L = [1, 2, 3, 4, 5]
L[1:3] = (100)
print(L)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ed4bb8658306> in <module>
#       1 #4
#       2 L = [1, 2, 3, 4, 5]
# ----> 3 L[1:3] = (100)
#       4 print(L)
#
# TypeError: can only assign an iterable

# %% [markdown]
# - 조각 안에 리스트를 대입할 때, 대입하려고 하는 대상이 다른 리스트여야 한다. 위 코드에서는 튜플이 아닌 정수 100이기때문에 에러가 뜬다.

# %%
#5
L = [1, 2, 3, 4, 5]
L[1:3] = (100, 101, 102)
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# - 슬라이싱을 사용하여 인덱스의 범위가 1~2인 값을 삭제하고 해당 위치에 (100,101,102) 튜플을 넣는 것이기 때문에 [1,100,101,102,4,5]가 출력된다.

# %%
#6
L = [1, 2, 3, 4, 5]
L[1:3] = [100, 101, 102] 
print(L)
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# - 슬라이싱을 사용하여 인덱스의 범위가 1~2인 값을 삭제하고 해당 위치에 [100,101,102] 리스트를 넣는 것이기 때문에 [1,100,101,102,4,5]가 출력된다.

# %%
#7
L = [1, 2, 3, 4, 5]
L[1:3] = [(100, 101, 102)]
print(L)
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# - 슬라이싱을 사용하여 인덱스의 범위가 1~2인 값을 삭제하고 해당 위치에 [(100,101,102)] 리스트 안의 원소인 튜플(100,101,102)를 넣는 것이기 때문에 [1,(100,101,102),4,5]가 출력된다.

# %%
#8
L = [1, 2, 3, 4, 5]
L[1:3] = [[100, 101, 102]]
print(L)
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# - 슬라이싱을 사용하여 인덱스의 범위가 1~2인 값을 삭제하고 해당 위치에 [[100,101,102]] 리스트 안의 원소인 리스트[100,101,102]를 넣는 것이기 때문에 [1,[100,101,102],4,5]가 출력된다.

# %% [markdown]
# ### Q2. 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.
# 1) 단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고
#
#
# 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
S = "Hello World and Python"

a = S.split(" ")
a = ' '.join(a[::-1])
print(a) #1

''.join(a.split())#2
# Out:
# Python and World Hello
# 'PythonandWorldHello'

# %% [markdown]
# ### Q3. 다음 코드를 보고 물음에 답하시오.

# %%
a = [1, 2, 3]
b = a * 3
print(a)
c = [a] * 3
print(b)
print(c)
# Out:
# [1, 2, 3]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %% [markdown]
# #### 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#
# a[0]=0

# %%
a[0] = 0
print(b)
print(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# #### 2) b와 c 객체의 차이는 무엇인가?
#
# b 객체는 a 리스트안의 요소를 3번 반복하여 [1, 2, 3, 1, 2, 3, 1, 2, 3]를 a와 레퍼런스가 관련이 없도록 생성하기 때문에 a의 변경사항이 적용되지 않는다.
#
#
# c 객체는 a 리스트를 3번 반복한 리스트를 생성한다. c객체는 a 객체의 레퍼런스를 3개 가지고 있으므로 a[0]=0로 변경하였을 때 [[0, 2, 3], [0, 2, 3], [0, 2, 3]] 변경된다.

# %% [markdown]
# ### Q4. 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
#
#
# s = '  first star   :   second star   :    third star  '
#
#
# l = ['first star', 'second star', 'third star']
# 1) for ~ in 문을 이용한 코드를 작성하시오.

# %%
s = ' first star : second star : third star '
l = s.split(":")
stripL = []

for i in l:
    stripL.append(i.strip())
    
stripL
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = ' first star : second star : third star '
l = s.split(":")
stripL = []

stripL = [i.strip() for i in l]
    
stripL
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# ### Q5. 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.
# 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)
#
# 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)

# %%
#1
# for ~ in 리터럴
def addall(list) :
    sum = 0
    for i in list :
        sum += i
    return sum
    
print(addall([1]))
print(addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 1
# 45

# %%
# 리스트 내포방식
def addall(list) :
    list = [i for i in list]
    return sum(list)

print(addall([1]))
print(addall([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 1
# 45

# %%
# 2
# for ~ in 리터럴
def addallodd(list) :
    sum = 0
    for i in list:
        if i%2==1:
            sum += i
    return sum
        
print (addallodd([1,3,5,6,7]))
print (addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 16
# 25

# %%
# 리스트 내포방식

def addallodd(list) :
    list = [i for i in list if i%2==1]
    return sum(list)

print (addallodd([1,3,5,6,7]))
print (addallodd([1, 2, 3, 4, 5, 6, 7, 8, 9]))
# Out:
# 16
# 25

# %% [markdown]
# ## Q6. 다음 코드를 보고 물음에 답하시오.

# %%
L1 = [1, 2, 3]
L2 = [4, 5, 6]
d = {'low':L1, 'high':L2}
e = d
f = d.copy()
print(d)
print(e)
print(f)

d['low'] = [10, 20, 30]
d['high'][1] = 500
print(d)
print(e)
print(f)
# Out:
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [1, 2, 3], 'high': [4, 5, 6]}
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [10, 20, 30], 'high': [4, 500, 6]}
# {'low': [1, 2, 3], 'high': [4, 500, 6]}

# %% [markdown]
# 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?
# - e는 d의 참조(레퍼런스)를 복사했기 때문에 d의 변경사항은 e에도 똑같이 적용된다.
#
#
# 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
# {'high': [4, 500, 6], 'low': [1, 2, 3]}
#
# - f는 d의 리스트의 내용을 복사하는 copy메소드를 사용하였기 때문에 shallow copy가 되었다. 따라서 d['low'] = [10,20,30]으로 바꾸어도 f는 원래의 L1([1,2,3])을 참조하고 있기 때문에 변화하지 않는다. d['high'][1]을 바꿀 경우에는 f의 L2도 d와 같은 L2의 레퍼런스를 참조하고 있기 때문에 레퍼런스 값의 원소를 변경했기 때문에 f에도 500으로 수정되는 영향을 끼치게 된다.

# %% [markdown]
# ### Q7. 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
# [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
# 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
#
# 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
#
# 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
#
# 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
#1 키의 알파벳 오름차순
d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}
d1 = sorted(d.items())
d1
# Out:
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]

# %%
#2 키의 알파벳 내림차순
d2 = sorted(d.items(),reverse = True)
d2
# Out:
# [('two', 2), ('three', 3), ('one', 1), ('four', 4), ('five', 5)]

# %%
#1 값의 오름차순
d3 = sorted(d.items(), key = lambda item : item[1])#value값인 item[1] 기준 정렬
d3
# Out:
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]

# %%
#1 값의 내림차순
d4 = sorted(d.items(), key = lambda item : item[1],reverse = True)
d4
# Out:
# [('five', 5), ('four', 4), ('three', 3), ('two', 2), ('one', 1)]

# %% [markdown]
# ### Q8. 다음 문제를 정확히 읽고 적합한 코딩을 제시하시오.
# length(X)를 다음과 같이 정의한다 : 10진수로 표현된 X의 자릿수
# Strange라는 숫자를 아래과 같이 정의한다.
# 음이 아닌 정수 중 자릿수가 1인 모든 숫자는 Strange이다.
# length(X) > 1 인 숫자 X 는 다음 2가지를 만족하면 Strange이다.
# X는 length(X)로 정확히 나누어 떨어진다.
# X / length(X) 가 strange이다.
#
# 이 문제에서 숫자 하나가 주어질 때, 이 숫자가 Strange인지 판단하는 함수 isStrange(num)을 작성하시오.
# isStrange(num) 함수가 재귀적인 함수가 되도록 작성해 보세요.

# %%
def length (X):
    return len(str(X))

def isStrange(num):
    if num < 0 : #음인 정수는 False 한다.
        return False
    
    else :
        num_len = length(num)
        if num_len == 1: #자릿수가 1일 경우 True (0도 포함)
            return True
        
        elif num_len > 1 :#자릿수가 1이상일 경우 조건 1을 검사하고 재귀적인 함수 구성을 통해 조건 2를 검사한다.
            if num%num_len == 0 and isStrange(int(num/num_len)):
                return True
            else :
                return False

print(isStrange(0))
print(isStrange(56))
print(isStrange(100))
print(isStrange(7882602506492313600))
print(isStrange(6012302549522098651))
# Out:
# True
# True
# False
# True
# False

# %% [markdown]
# ### Q9. 다음 문제를 정확히 읽고 적합한 코딩을 제시하시오.
#
# 1번 그룹, 2번 그룹, ... n번 그룹으로 번호가 매겨진 총 n개의 그룹이 존재하고, ith 그룹에는 임의의 팀원 수 ai 명이 있다.
# 하나의 버스 정류장이 있고, 버스는 오직 한 대만 운영한다. 버스는 버스 정류장에 도착하고 모든 그룹은 버스를 통해 여행하길 원한다.
# 하지만, 같은 그룹에 속한 팀원들은 분리되기를 원치 않는다. 그래서 그룹의 모든 팀원이 탈 수 있을 때 에만 그 그룹은 버스에 탑승한다.
# 또한, 이들은 그룹의 번호순으로 여행을 하길 원한다. 예를 들어, 3번 그룹은 1번 그룹과 2번 그룹이 여행을 한 뒤에 버스를 탈 수 있거나, 1번 그룹과 2번 그룹이 이미 버스에 탑승한 상태에 있을 때 동시에 버스를 탈 수 있다.
# 마지막으로, 버스는 빈 좌석이 없을 때 에만 여행을 떠난다.
#
# 이 문제에서 각 그룹의 팀원 수가 리스트로 주어질 때, 가능한 모든 버스의 사이즈 x(x명의 사람들이 동시에 탈 수 있음)를 반환하는 함수 solve(a) 를 작성하시오.
# [주의] 반드시 계산 복잡도를 최대한 낮추세요. 아래 예시 3번을 실행했을 때 결과가 바로 나타날 수 있도록!!

# %% [markdown]
# ### Incremental Project 2

# %% [markdown]
# 의미있는 문자열만을 뽑아내기 위해서 전체적으로 문자열의 인덱스 성질을 이용하여 코드를 작성하였다.
#
#
# 고려해야 하는 사항은 아래와 같다.
# - case1. < ~~ > 꺽은 괄호 내에 있는 내용 제거 (<>가 중첩되는 경우에도 제거되어야 한다)
# - case2. <> ~~ </> 의 태그 속 내용 제거 ex) style,script
# - case3. 의미없는 특수문자 제거
#
# 문자열의 인덱스(sNum)를 수행할 때마다 1씩 증가 시켜준다.
#
#  - case 1에 대해서는 < 를 발견 시 >을 발견하기 전까지 문자를 저장하지 않음으로써 내용을 제거한다.
#  - case 2에 대해서는 특정 태그 안에서는 문자열이 아닌 것도 존재하기에, 특정 태그(script, style)를 지정하여 그 사이의 값은 문자를 저장하지 않음으로써 내용을 제거한다. 이 밖에도 html에서 style과 script와 같이 작동하는 것이 있다면 check_case2 함수를 이용하여 추가하면 된다. 또한 <>의 내부에 예를 들어 내용이 <1<2>3>과 구성되어 있다면 >를 만나 3의 내용을 제거하지 못하는 경우를 고려하여 중첩됐을 경우도 고려한다.
#  - case 3에 대해서는 의미없는 특수문자를 제거해주기 위하여, 의미없는 특수문자열에 해당하는 문자가 있다면 인덱스 값을 넘겨 내용을 제거한다.

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def check_case2(sNum, s, source):
    sNum = sNum + len(s) #< s > 제거
    while source[sNum:sNum+len('/'+s)] != '/'+ s : #</s> 전까지 제거
        sNum += 1
    return sNum


def search_engine1(source):
   
    sNum = 0 # 문자열의 검색 위치 저장
    text = '' # 의미있는 문자 저장

    while  sNum < len(source) :
        #case1
        if source[sNum] == "<" :
            cnt = 0
            sNum += 1 
            #case 2
            if source[sNum:sNum+len('script')] == 'script' : #script 태그 속 내용 제거
                sNum = check_case2(sNum,'script',source)
            if source[sNum : sNum+len('style')] == 'style' : #style 태그 속 내용 제거
                sNum = check_case2(sNum,'style',source)
                
            while source[sNum] != '>' or cnt != 0 :
                if source[sNum]== '<' :  #태그가 중첩되었을 때 제거
                    cnt += 1
                elif source[sNum]=='>':  
                    cnt -= 1
                sNum += 1
            sNum += 1

        #case3 특수문자 제거
        elif source[sNum] in string.punctuation : #특수문자 제거
            sNum += 1

        else : #위의 case가 아닐 시 의미있는 문자열에 추가해줌.
            text += source[sNum]
            sNum += 1

    lst = text.split() 
    wordCount = {}

    for word in lst :
        wordCount[word]=wordCount.get(word,0)+1
        
    print(wordCount)

# %%
import requests
req = requests.get('http://cse.koreatech.ac.kr')
search_engine1(req.text)
# Out:
# {'Page': 1, 'Redirection': 1, '사이트': 1, '폐쇄': 1, '안내': 1, '특성화': 1, '사업': 1, '종료로': 1, '인한': 1, 'itcswkoreatechackr': 1, '사이트가': 1, '폐쇄되었습니다': 1, '잠시후': 1, '컴퓨터공학부': 1, '홈페이지로': 1, '자동': 1, '연결': 1, '됩니다': 1, 'If': 1, 'you': 1, 'are': 1, 'not': 1, 'redirected': 1, 'automatically': 1, 'follow': 1, 'the': 1, 'link': 1, 'to': 1, 'csekoreatechackr': 1}

# %%
req = requests.get('https://www.koreatech.ac.kr')
search_engine1(req.text)
# Out:
# {'한국기술교육대학교': 11, '닫기': 1, 'Link': 1, 'Service': 1, '재학생': 3, '학생이': 3, '행복한': 3, '대학': 7, '온라인교육지원': 3, '생활관': 2, '원격지원': 2, '오늘의': 2, '식단': 2, '학사종합시스템': 1, '인터넷증명발급': 3, '동아리안내': 2, '입학정보': 3, '코리아텍의': 3, '입학정보를': 3, '제공합니다': 6, '취업정보': 3, '최신': 3, '취업관련': 3, '정보를': 3, '교직원': 3, '아우누리': 1, '무선랜신청': 1, '교육장비검색': 1, '일반인': 3, '코리아텍소개': 1, 'VISION2020': 2, 'PLUS': 2, '언론기사': 1, '학부소개': 1, '대학원소개': 1, '캠퍼스투어': 1, '찾아오시는길': 2, '전화번호찾기': 1, '코리아텍': 1, '특장점': 1, '자세히': 1, '보기': 1, '중앙일보대학평가‘교육중심대학’': 1, '1위': 4, '코리아텍은': 1, '중앙일보대학평가': 1, '11년': 1, '연속으로': 1, '“교육중심대학': 1, '1위”': 1, '의': 1, '성과를': 1, '이루었습니다': 1, '스킵네비게이션': 1, '본문바로가기': 1, '주메뉴바로가기': 1, '통학·셔틀버스': 1, '명칭': 2, 'whome': 1, '대표홈': 1, 'home': 1, '홈': 1, 'join': 1, '회원가입': 1, 'login': 1, '로그인': 1, 'my': 1, '마이페이지': 1, 'logout': 1, '로그아웃': 1, 'contact': 1, 'Contact':
음': 7, '오리지널': 2, '콘텐츠': 2, 'TV하이라이트': 2, '주요장면': 2, '커피': 1, '한잔': 1, '할까요': 1, '메뉴판': 1, '만들기에': 1, '진심인': 1, '초보': 1, '바리스타': 1, '옹성우': 1, '징크스': 1, '찬희의': 1, '직진': 1, '고백을': 1, '받은': 1, '은서': 1, '반응': 1, '그림자': 1, '미녀': 1, '학교에서': 1, '왕따인': 1, '여고생이': 1, 'SNS에서는': 1, '고기리': 1, '돈스파이크': 1, '고기를': 1 ...

# %%
req = requests.get('https://www.nytimes.com/')
search_engine1(req.text)
# Out:
# {'The': 16, 'New': 20, 'York': 16, 'Times': 3, 'Breaking': 1, 'News': 3, 'US': 2, 'World': 2, 'and': 21, 'Videos': 1, 'SectionsSEARCHSkip': 1, 'to': 33, 'contentSkip': 1, 'site': 1, 'indexUSInternationalCanadaEspañol中文Today’s': 1, 'PaperWorldUSPoliticsNYBusinessOpinionTechScienceHealthSportsArtsBooksStyleFoodTravelMagazineT': 1, 'MagazineReal': 1, 'EstateVideoHouse': 1, 'Finds': 3, 'Bannon': 2, 'in': 19, 'Contempt': 1, 'for': 20, 'Defying': 1, 'Jan': 3, '6': 2, 'Inquiry': 1, 'SubpoenaSteve': 1, 'an': 5, 'ally': 2, 'of': 34, 'former': 3, 'President': 2, 'Trump': 6, 'has': 6, 'stonewalled': 1, 'the': 48, 'Capitol': 1, 'riot': 1, 'inquiry': 1, 'Justice': 1, 'Department': 1, 'will': 4, 'now': 1, 'decide': 1, 'whether': 1, 'prosecute': 1, 'himThe': 1, 'vote': 1, 'came': 1, 'after': 4, 'a': 27, 'bitterly': 1, 'partisan': 1, 'debate': 1, 'over': 1, 'attack': 1, 'as': 9, 'Republicans': 1, 'sought': 2, 'deflect': 1, 'questions': 3, 'about': 4, 'Mr': 1, 'Trump’s': 1, 'role': 1, 'violenceCarlos': 1, 'Bernate': 1, 'TimesLiz': 1, 'Cheney’s': 1, 'Consultants': 1, 'Are': 3, 'Given': 1, 'Ultimatum': 1, 'Drop': 1, 'Her': 2, 'or': 2, 'Be': 2, 'DroppedThe': 1, 'message': 1, 'delivered': 1, 'by': 3, 'lobbyist': 1, 'close': 2, 'House': 1, 'minority': 1, 'leader': 1, 'Kevin': 1, 'McCarthy': 1, 'already': 1, 'led': 1, 'one': 4, 'Republican': 2, 'firm': 1, 'cut': 1, 'tiesThanks': 1, 'Wall': 1, 'Street': 1, 'fad': 1, 'gained': 1, 'access': 1, 'millions': 1, 'launch': 1, 'social': 1, 'media': 1, 'companyAttorney': 1, 'General': 1, 'Merrick': 1, 'Garland': 1, 'sidestepped': 1, 'investigation': 2, 'during': 1, 'congressional': 1, 'hearingAdvertisementContinue': 1, 'reading': 5, 'main': 5, 'storyBreakingCDC': 1, 'Recommends': 1, 'Covid': 3, 'Booster': 1, 'Shots': 1, 'Millions': 1, 'AmericansRecipients': 1, 'Moderna': 1, 'JampJ': 1, 'vaccines': 1, 'may': 1, 'receive': 1, 'extra': 1, 'doses': 1, 'opening': 2, 'door': 1, 'many': 3, 'seek': 1, 'out': 1, 'booster': 1, 'shot': 1, 'early': 2, 'FridayRise': 1, 'Cases': 2, 'Deaths': 1, 'Tests': 1, 'Britain’s': 1, 'Gamble': 1, 'on': 11, 'Few': 1, 'Virus': 2, 'RestrictionsThe': 1, 'country’s': 1, 'grand': 1, 'experiment': 1, '—': 4, 'up': 1, 'with': 4, 'hardly': 1, 'any': 1, 'restrictions': 1, 'is': 6, 'facing': 1, 'its': 1, 'toughest': 1, 'challenge': 1, 'yet': 1, 'Tracking': 1, 'Coronavirus': 1, '›': 6, 'United': 3, 'States': 2, 'StatesAvg': 1, 'Oct': 1, '20': 1, '14day': 1, 'change': 1, 'cases': 1, '76496': 1, '–25': 1, 'deaths': 1, '1532': 1, '–15': 1, 'hot': 2, 'spots': 2, 'Vaccinations': 1, 'Global': 3, 'Other': 2, 'trackers': 2, 'Choose': 1, 'your': 5, 'own': 2, 'places': 2, 'vaccinationsAustraliaUKAlaskaMontIdahoHospitalsVaccine': 2, 'development': 1, 'developmentChoose': 1, 'Energizing': 1, 'Conservative': 1, 'Voters': 1, 'One': 1, 'School': 1, 'Board': 1, 'Election': 1, 'at': 5, 'TimeRepublicans': 1, 'hope': 1, 'that': 7, 'concerns': 1, 'critical': 1, 'race': 1, 'theory': 1, 'can': 4, 'help': 2, 'them': 2, 'midterm': 1, 'elections': 1, 'issue': 1, 'torn': 1, 'apart': 1, 'Wisconsin': 1, 'suburbMorry': 1, 'GashAssociated': 1, 'PressA': 1, 'lawyer': 1, 'oversee': 1, 'election': 1, 'review': 1, 'Texas': 1, 'he': 3, 'was': 4, 'appointed': 1, 'state’s': 1, 'secretary': 1, 'stateOn': 1, 'Politics': 1, 'nominee': 1, 'Virginia': 1, 'governor': 1, 'pushing': 1, 'voting': 1, 'despite': 1, 'catering': 1, 'baseClimate': 1, 'Change': 2, 'Seen': 1, 'Widening': 1, 'Threat': 1, 'National': 2, 'SecurityIntelligence': 1, 'defense': 1, 'agencies': 1, 'issued': 1, 'reports': 1, 'warning': 1, 'warming': 1, 'planet': 1, 'increase': 1, 'strife': 1, 'between': 1, 'countries': 1, 'spur': 1, 'migrationDavid': 1, 'GoldmanAssociated': 1, 'PressThe': 1, 'Financial': 1, 'Stability': 1, 'Oversight': 1, 'Council': 1, 'warned': 1, 'climate': 1, 'change’s': 1, 'risks': 1, 'financial': 1, 'system‘It’s': 1, 'Terror’': 1, 'In': 1, 'Haiti': 1, 'Gangs': 1, 'Gain': 1, 'PowerThe': 1, 'dominance': 1, 'gangs': 1, 'across': 2, 'country': 1, 'expanded ...

# %% [markdown]
# ## 소감
# 점점 과제가 어려워지고 있지만, 그만큼 얻는 것도 큰 것 같습니다. 이론적인 부분에 대한 문제 왜 이렇게 작동되는지를 묻는 문제에서 저의 이론적 오류를 고치게 되는 계기가 되어 좋았던 것 같습니다. 여러 경우를 생각하고 과제를 해결하려고 노력하고 있으나, 제가 놓치는 케이스를 발견하지 못할 때 아쉽습니다.
